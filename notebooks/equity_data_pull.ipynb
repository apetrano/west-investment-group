# %%
import sys
sys.path.append('../src/')
from TWIG_utils import *

# %%
stock_list = ['AMZN', 'TSLA', 'SNAP', 'INTC', 'PINS', 'SOFI', 'APPLE', 'F', 'BAC', 'T', 'GOOGL']
date_start = '2022-01-01'
date_end = '2023-04-28'

client = RESTClient(auth_key="JeeOjlOPBe5aTiQ_Jb39raRqlam45uAO")

# %%
stock_data = get_ticker_daily_data(client, stock_list[0], date_start, date_end)
# Out:
# Starting data pull for AMZN...
# (pid=18506) 2023-04-29 12:15:29,980	ERROR serialization.py:253 -- No module named 'TWIG_utils'
# (pid=18506) Traceback (most recent call last):
# (pid=18506)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 251, in deserialize_objects
# (pid=18506)     obj = self._deserialize_object(data, metadata, object_ref)
# (pid=18506)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 189, in _deserialize_object
# (pid=18506)     return self._deserialize_msgpack_data(data, metadata_fields)
# (pid=18506)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 167, in _deserialize_msgpack_data
# (pid=18506)     python_objects = self._deserialize_pickle5_data(pickle5_data)
# (pid=18506)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 157, in _deserialize_pickle5_data
# (pid=18506)     obj = pickle.loads(in_band)
# (pid=18506) ModuleNotFoundError: No module named 'TWIG_utils'
# (pid=18509) 2023-04-29 12:15:29,978	ERROR serialization.py:253 -- No module named 'TWIG_utils'
# (pid=18509) Traceback (most recent call last):
# (pid=18509)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 251, in deserialize_objects
# (pid=18509)     obj = self._deserialize_object(data, metadata, object_ref)
# (pid=18509)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 189, in _deserialize_object
# (pid=18509)     return self._deserialize_msgpack_data(data, metadata_fields)
# (pid=18509)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 167, in _deserialize_msgpack_data
# (pid=18509)     python_objects = self._deserialize_pickle5_data(pickle5_data)
# (pid=18509)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 157, in _deserialize_pickle5_data
# (pid=18509)     obj = pickle.loads(in_band)
# (pid=18509) ModuleNotFoundError: No module named 'TWIG_utils'
# (pid=18507) 2023-04-29 12:15:29,980	ERROR serialization.py:253 -- No module named 'TWIG_utils'
# (pid=18507) Traceback (most recent call last):
# (pid=18507)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 251, in deserialize_objects
# (pid=18507)     obj = self._deserialize_object(data, metadata, object_ref)
# (pid=18507)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 189, in _deserialize_object
# (pid=18507)     return self._deserialize_msgpack_data(data, metadata_fields)
# (pid=18507)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 167, in _deserialize_msgpack_data
# (pid=18507)     python_objects = self._deserialize_pickle5_data(pickle5_data)
# (pid=18507)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 157, in _deserialize_pickle5_data
# (pid=18507)     obj = pickle.loads(in_band)
# (pid=18507) ModuleNotFoundError: No module named 'TWIG_utils'
# (pid=18508) 2023-04-29 12:15:29,979	ERROR serialization.py:253 -- No module named 'TWIG_utils'
# (pid=18508) Traceback (most recent call last):
# (pid=18508)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 251, in deserialize_objects
# (pid=18508)     obj = self._deserialize_object(data, metadata, object_ref)
# (pid=18508)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 189, in _deserialize_object
# (pid=18508)     return self._deserialize_msgpack_data(data, metadata_fields)
# (pid=18508)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 167, in _deserialize_msgpack_data
# (pid=18508)     python_objects = self._deserialize_pickle5_data(pickle5_data)
# (pid=18508)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 157, in _deserialize_pickle5_data
# (pid=18508)     obj = pickle.loads(in_band)
# (pid=18508) ModuleNotFoundError: No module named 'TWIG_utils'
# (pid=18504) 2023-04-29 12:15:29,982	ERROR serialization.py:253 -- No module named 'TWIG_utils'
# (pid=18504) Traceback (most recent call last):
# (pid=18504)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 251, in deserialize_objects
# (pid=18504)     obj = self._deserialize_object(data, metadata, object_ref)
# (pid=18504)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 189, in _deserialize_object
# (pid=18504)     return self._deserialize_msgpack_data(data, metadata_fields)
# (pid=18504)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 167, in _deserialize_msgpack_data
# (pid=18504)     python_objects = self._deserialize_pickle5_data(pickle5_data)
# (pid=18504)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 157, in _deserialize_pickle5_data
# (pid=18504)     obj = pickle.loads(in_band)
# (pid=18504) ModuleNotFoundError: No module named 'TWIG_utils'
# (pid=18505) 2023-04-29 12:15:29,983	ERROR serialization.py:253 -- No module named 'TWIG_utils'
# (pid=18505) Traceback (most recent call last):
# (pid=18505)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 251, in deserialize_objects
# (pid=18505)     obj = self._deserialize_object(data, metadata, object_ref)
# (pid=18505)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 189, in _deserialize_object
# (pid=18505)     return self._deserialize_msgpack_data(data, metadata_fields)
# (pid=18505)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 167, in _deserialize_msgpack_data
# (pid=18505)     python_objects = self._deserialize_pickle5_data(pickle5_data)
# (pid=18505)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 157, in _deserialize_pickle5_data
# (pid=18505)     obj = pickle.loads(in_band)
# (pid=18505) ModuleNotFoundError: No module named 'TWIG_utils'
# (pid=18503) 2023-04-29 12:15:29,982	ERROR serialization.py:253 -- No module named 'TWIG_utils'
# (pid=18503) Traceback (most recent call last):
# (pid=18503)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 251, in deserialize_objects
# (pid=18503)     obj = self._deserialize_object(data, metadata, object_ref)
# (pid=18503)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 189, in _deserialize_object
# (pid=18503)     return self._deserialize_msgpack_data(data, metadata_fields)
# (pid=18503)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 167, in _deserialize_msgpack_data
# (pid=18503)     python_objects = self._deserialize_pickle5_data(pickle5_data)
# (pid=18503)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 157, in _deserialize_pickle5_data
# (pid=18503)     obj = pickle.loads(in_band)
# (pid=18503) ModuleNotFoundError: No module named 'TWIG_utils'
# (pid=18510) 2023-04-29 12:15:29,983	ERROR serialization.py:253 -- No module named 'TWIG_utils'
# (pid=18510) Traceback (most recent call last):
# (pid=18510)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 251, in deserialize_objects
# (pid=18510)     obj = self._deserialize_object(data, metadata, object_ref)
# (pid=18510)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 189, in _deserialize_object
# (pid=18510)     return self._deserialize_msgpack_data(data, metadata_fields)
# (pid=18510)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 167, in _deserialize_msgpack_data
# (pid=18510)     python_objects = self._deserialize_pickle5_data(pickle5_data)
# (pid=18510)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 157, in _deserialize_pickle5_data
# (pid=18510)     obj = pickle.loads(in_band)
# (pid=18510) ModuleNotFoundError: No module named 'TWIG_utils'
# (pid=18509) 2023-04-29 12:15:30,752	ERROR serialization.py:253 -- No module named 'TWIG_utils'
# (pid=18509) Traceback (most recent call last):
# (pid=18509)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 251, in deserialize_objects
# (pid=18509)     obj = self._deserialize_object(data, metadata, object_ref)
# (pid=18509)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 189, in _deserialize_object
# (pid=18509)     return self._deserialize_msgpack_data(data, metadata_fields)
# (pid=18509)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 167, in _deserialize_msgpack_data
# (pid=18509)     python_objects = self._deserialize_pickle5_data(pickle5_data)
# (pid=18509)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 157, in _deserialize_pickle5_data
# (pid=18509)     obj = pickle.loads(in_band)
# (pid=18509) ModuleNotFoundError: No module named 'TWIG_utils'
# (pid=18509) 2023-04-29 12:15:30,754	ERROR serialization.py:253 -- No module named 'TWIG_utils'
# (pid=18509) Traceback (most recent call last):
# (pid=18509)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 251, in deserialize_objects
# (pid=18509)     obj = self._deserialize_object(data, metadata, object_ref)
# (pid=18509)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 189, in _deserialize_object
# (pid=18509)     return self._deserialize_msgpack_data(data, metadata_fields)
# (pid=18509)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 167, in _deserialize_msgpack_data
# (pid=18509)     python_objects = self._deserialize_pickle5_data(pickle5_data)
# (pid=18509)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 157, in _deserialize_pickle5_data
# (pid=18509)     obj = pickle.loads(in_band)
# (pid=18509) ModuleNotFoundError: No module named 'TWIG_utils'
# (pid=18509) 2023-04-29 12:15:30,756	ERROR serialization.py:253 -- No module named 'TWIG_utils'
# (pid=18509) Traceback (most recent call last):
# (pid=18509)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 251, in deserialize_objects
# (pid=18509)     obj = self._deserialize_object(data, metadata, object_ref)
# (pid=18509)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 189, in _deserialize_object
# (pid=18509)     return self._deserialize_msgpack_data(data, metadata_fields)
# (pid=18509)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 167, in _deserialize_msgpack_data
# (pid=18509)     python_objects = self._deserialize_pickle5_data(pickle5_data)
# (pid=18509)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 157, in _deserialize_pickle5_data
# (pid=18509)     obj = pickle.loads(in_band)
# (pid=18509) ModuleNotFoundError: No module named 'TWIG_utils'
# (pid=18507) 2023-04-29 12:15:30,752	ERROR serialization.py:253 -- No module named 'TWIG_utils'
# (pid=18507) Traceback (most recent call last):
# (pid=18507)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 251, in deserialize_objects
# (pid=18507)     obj = self._deserialize_object(data, metadata, object_ref)
# (pid=18507)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 189, in _deserialize_object
# (pid=18507)     return self._deserialize_msgpack_data(data, metadata_fields)
# (pid=18507)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 167, in _deserialize_msgpack_data
# (pid=18507)     python_objects = self._deserialize_pickle5_data(pickle5_data)
# (pid=18507)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 157, in _deserialize_pickle5_data
# (pid=18507)     obj = pickle.loads(in_band)
# (pid=18507) ModuleNotFoundError: No module named 'TWIG_utils'
# (pid=18507) 2023-04-29 12:15:30,754	ERROR serialization.py:253 -- No module named 'TWIG_utils'
# (pid=18507) Traceback (most recent call last):
# (pid=18507)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 251, in deserialize_objects
# (pid=18507)     obj = self._deserialize_object(data, metadata, object_ref)
# (pid=18507)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 189, in _deserialize_object
# (pid=18507)     return self._deserialize_msgpack_data(data, metadata_fields)
# (pid=18507)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 167, in _deserialize_msgpack_data
# (pid=18507)     python_objects = self._deserialize_pickle5_data(pickle5_data)
# (pid=18507)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 157, in _deserialize_pickle5_data
# (pid=18507)     obj = pickle.loads(in_band)
# (pid=18507) ModuleNotFoundError: No module named 'TWIG_utils'
# (pid=18507) 2023-04-29 12:15:30,756	ERROR serialization.py:253 -- No module named 'TWIG_utils'
# (pid=18507) Traceback (most recent call last):
# (pid=18507)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 251, in deserialize_objects
# (pid=18507)     obj = self._deserialize_object(data, metadata, object_ref)
# (pid=18507)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 189, in _deserialize_object
# (pid=18507)     return self._deserialize_msgpack_data(data, metadata_fields)
# (pid=18507)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 167, in _deserialize_msgpack_data
# (pid=18507)     python_objects = self._deserialize_pickle5_data(pickle5_data)
# (pid=18507)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 157, in _deserialize_pickle5_data
# (pid=18507)     obj = pickle.loads(in_band)
# (pid=18507) ModuleNotFoundError: No module named 'TWIG_utils'
# (pid=18506) 2023-04-29 12:15:30,816	ERROR serialization.py:253 -- No module named 'TWIG_utils'
# (pid=18506) Traceback (most recent call last):
# (pid=18506)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 251, in deserialize_objects
# (pid=18506)     obj = self._deserialize_object(data, metadata, object_ref)
# (pid=18506)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 189, in _deserialize_object
# (pid=18506)     return self._deserialize_msgpack_data(data, metadata_fields)
# (pid=18506)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 167, in _deserialize_msgpack_data
# (pid=18506)     python_objects = self._deserialize_pickle5_data(pickle5_data)
# (pid=18506)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 157, in _deserialize_pickle5_data
# (pid=18506)     obj = pickle.loads(in_band)
# (pid=18506) ModuleNotFoundError: No module named 'TWIG_utils'
# (pid=18506) 2023-04-29 12:15:30,819	ERROR serialization.py:253 -- No module named 'TWIG_utils'
# (pid=18506) Traceback (most recent call last):
# (pid=18506)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 251, in deserialize_objects
# (pid=18506)     obj = self._deserialize_object(data, metadata, object_ref)
# (pid=18506)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 189, in _deserialize_object
# (pid=18506)     return self._deserialize_msgpack_data(data, metadata_fields)
# (pid=18506)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 167, in _deserialize_msgpack_data
# (pid=18506)     python_objects = self._deserialize_pickle5_data(pickle5_data)
# (pid=18506)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 157, in _deserialize_pickle5_data
# (pid=18506)     obj = pickle.loads(in_band)
# (pid=18506) ModuleNotFoundError: No module named 'TWIG_utils'
# (pid=18506) 2023-04-29 12:15:30,821	ERROR serialization.py:253 -- No module named 'TWIG_utils'
# (pid=18506) Traceback (most recent call last):
# (pid=18506)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 251, in deserialize_objects
# (pid=18506)     obj = self._deserialize_object(data, metadata, object_ref)
# (pid=18506)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 189, in _deserialize_object
# (pid=18506)     return self._deserialize_msgpack_data(data, metadata_fields)
# (pid=18506)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 167, in _deserialize_msgpack_data
# (pid=18506)     python_objects = self._deserialize_pickle5_data(pickle5_data)
# (pid=18506)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 157, in _deserialize_pickle5_data
# (pid=18506)     obj = pickle.loads(in_band)
# (pid=18506) ModuleNotFoundError: No module named 'TWIG_utils'
# (pid=18508) 2023-04-29 12:15:30,833	ERROR serialization.py:253 -- No module named 'TWIG_utils'
# (pid=18508) Traceback (most recent call last):
# (pid=18508)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 251, in deserialize_objects
# (pid=18508)     obj = self._deserialize_object(data, metadata, object_ref)
# (pid=18508)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 189, in _deserialize_object
# (pid=18508)     return self._deserialize_msgpack_data(data, metadata_fields)
# (pid=18508)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 167, in _deserialize_msgpack_data
# (pid=18508)     python_objects = self._deserialize_pickle5_data(pickle5_data)
# (pid=18508)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 157, in _deserialize_pickle5_data
# (pid=18508)     obj = pickle.loads(in_band)
# (pid=18508) ModuleNotFoundError: No module named 'TWIG_utils'
# (pid=18508) 2023-04-29 12:15:30,834	ERROR serialization.py:253 -- No module named 'TWIG_utils'
# (pid=18508) Traceback (most recent call last):
# (pid=18508)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 251, in deserialize_objects
# (pid=18508)     obj = self._deserialize_object(data, metadata, object_ref)
# (pid=18508)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 189, in _deserialize_object
# (pid=18508)     return self._deserialize_msgpack_data(data, metadata_fields)
# (pid=18508)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 167, in _deserialize_msgpack_data
# (pid=18508)     python_objects = self._deserialize_pickle5_data(pickle5_data)
# (pid=18508)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 157, in _deserialize_pickle5_data
# (pid=18508)     obj = pickle.loads(in_band)
# (pid=18508) ModuleNotFoundError: No module named 'TWIG_utils'
# (pid=18508) 2023-04-29 12:15:30,836	ERROR serialization.py:253 -- No module named 'TWIG_utils'
# (pid=18508) Traceback (most recent call last):
# (pid=18508)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 251, in deserialize_objects
# (pid=18508)     obj = self._deserialize_object(data, metadata, object_ref)
# (pid=18508)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 189, in _deserialize_object
# (pid=18508)     return self._deserialize_msgpack_data(data, metadata_fields)
# (pid=18508)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 167, in _deserialize_msgpack_data
# (pid=18508)     python_objects = self._deserialize_pickle5_data(pickle5_data)
# (pid=18508)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 157, in _deserialize_pickle5_data
# (pid=18508)     obj = pickle.loads(in_band)
# (pid=18508) ModuleNotFoundError: No module named 'TWIG_utils'
# (pid=18504) 2023-04-29 12:15:30,842	ERROR serialization.py:253 -- No module named 'TWIG_utils'
# (pid=18504) Traceback (most recent call last):
# (pid=18504)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 251, in deserialize_objects
# (pid=18504)     obj = self._deserialize_object(data, metadata, object_ref)
# (pid=18504)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 189, in _deserialize_object
# (pid=18504)     return self._deserialize_msgpack_data(data, metadata_fields)
# (pid=18504)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 167, in _deserialize_msgpack_data
# (pid=18504)     python_objects = self._deserialize_pickle5_data(pickle5_data)
# (pid=18504)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 157, in _deserialize_pickle5_data
# (pid=18504)     obj = pickle.loads(in_band)
# (pid=18504) ModuleNotFoundError: No module named 'TWIG_utils'
# (pid=18504) 2023-04-29 12:15:30,845	ERROR serialization.py:253 -- No module named 'TWIG_utils'
# (pid=18504) Traceback (most recent call last):
# (pid=18504)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 251, in deserialize_objects
# (pid=18504)     obj = self._deserialize_object(data, metadata, object_ref)
# (pid=18504)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 189, in _deserialize_object
# (pid=18504)     return self._deserialize_msgpack_data(data, metadata_fields)
# (pid=18504)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 167, in _deserialize_msgpack_data
# (pid=18504)     python_objects = self._deserialize_pickle5_data(pickle5_data)
# (pid=18504)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 157, in _deserialize_pickle5_data
# (pid=18504)     obj = pickle.loads(in_band)
# (pid=18504) ModuleNotFoundError: No module named 'TWIG_utils'
# (pid=18504) 2023-04-29 12:15:30,847	ERROR serialization.py:253 -- No module named 'TWIG_utils'
# (pid=18504) Traceback (most recent call last):
# (pid=18504)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 251, in deserialize_objects
# (pid=18504)     obj = self._deserialize_object(data, metadata, object_ref)
# (pid=18504)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 189, in _deserialize_object
# (pid=18504)     return self._deserialize_msgpack_data(data, metadata_fields)
# (pid=18504)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 167, in _deserialize_msgpack_data
# (pid=18504)     python_objects = self._deserialize_pickle5_data(pickle5_data)
# (pid=18504)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 157, in _deserialize_pickle5_data
# (pid=18504)     obj = pickle.loads(in_band)
# (pid=18504) ModuleNotFoundError: No module named 'TWIG_utils'
# (pid=18505) 2023-04-29 12:15:30,856	ERROR serialization.py:253 -- No module named 'TWIG_utils'
# (pid=18505) Traceback (most recent call last):
# (pid=18505)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 251, in deserialize_objects
# (pid=18505)     obj = self._deserialize_object(data, metadata, object_ref)
# (pid=18505)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 189, in _deserialize_object
# (pid=18505)     return self._deserialize_msgpack_data(data, metadata_fields)
# (pid=18505)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 167, in _deserialize_msgpack_data
# (pid=18505)     python_objects = self._deserialize_pickle5_data(pickle5_data)
# (pid=18505)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 157, in _deserialize_pickle5_data
# (pid=18505)     obj = pickle.loads(in_band)
# (pid=18505) ModuleNotFoundError: No module named 'TWIG_utils'
# (pid=18505) 2023-04-29 12:15:30,858	ERROR serialization.py:253 -- No module named 'TWIG_utils'
# (pid=18505) Traceback (most recent call last):
# (pid=18505)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 251, in deserialize_objects
# (pid=18505)     obj = self._deserialize_object(data, metadata, object_ref)
# (pid=18505)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 189, in _deserialize_object
# (pid=18505)     return self._deserialize_msgpack_data(data, metadata_fields)
# (pid=18505)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 167, in _deserialize_msgpack_data
# (pid=18505)     python_objects = self._deserialize_pickle5_data(pickle5_data)
# (pid=18505)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 157, in _deserialize_pickle5_data
# (pid=18505)     obj = pickle.loads(in_band)
# (pid=18505) ModuleNotFoundError: No module named 'TWIG_utils'
# (pid=18505) 2023-04-29 12:15:30,860	ERROR serialization.py:253 -- No module named 'TWIG_utils'
# (pid=18505) Traceback (most recent call last):
# (pid=18505)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 251, in deserialize_objects
# (pid=18505)     obj = self._deserialize_object(data, metadata, object_ref)
# (pid=18505)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 189, in _deserialize_object
# (pid=18505)     return self._deserialize_msgpack_data(data, metadata_fields)
# (pid=18505)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 167, in _deserialize_msgpack_data
# (pid=18505)     python_objects = self._deserialize_pickle5_data(pickle5_data)
# (pid=18505)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 157, in _deserialize_pickle5_data
# (pid=18505)     obj = pickle.loads(in_band)
# (pid=18505) ModuleNotFoundError: No module named 'TWIG_utils'
# (pid=18503) 2023-04-29 12:15:30,809	ERROR serialization.py:253 -- No module named 'TWIG_utils'
# (pid=18503) Traceback (most recent call last):
# (pid=18503)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 251, in deserialize_objects
# (pid=18503)     obj = self._deserialize_object(data, metadata, object_ref)
# (pid=18503)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 189, in _deserialize_object
# (pid=18503)     return self._deserialize_msgpack_data(data, metadata_fields)
# (pid=18503)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 167, in _deserialize_msgpack_data
# (pid=18503)     python_objects = self._deserialize_pickle5_data(pickle5_data)
# (pid=18503)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 157, in _deserialize_pickle5_data
# (pid=18503)     obj = pickle.loads(in_band)
# (pid=18503) ModuleNotFoundError: No module named 'TWIG_utils'
# (pid=18503) 2023-04-29 12:15:30,811	ERROR serialization.py:253 -- No module named 'TWIG_utils'
# (pid=18503) Traceback (most recent call last):
# (pid=18503)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 251, in deserialize_objects
# (pid=18503)     obj = self._deserialize_object(data, metadata, object_ref)
# (pid=18503)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 189, in _deserialize_object
# (pid=18503)     return self._deserialize_msgpack_data(data, metadata_fields)
# (pid=18503)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 167, in _deserialize_msgpack_data
# (pid=18503)     python_objects = self._deserialize_pickle5_data(pickle5_data)
# (pid=18503)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 157, in _deserialize_pickle5_data
# (pid=18503)     obj = pickle.loads(in_band)
# (pid=18503) ModuleNotFoundError: No module named 'TWIG_utils'
# (pid=18503) 2023-04-29 12:15:30,813	ERROR serialization.py:253 -- No module named 'TWIG_utils'
# (pid=18503) Traceback (most recent call last):
# (pid=18503)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 251, in deserialize_objects
# (pid=18503)     obj = self._deserialize_object(data, metadata, object_ref)
# (pid=18503)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 189, in _deserialize_object
# (pid=18503)     return self._deserialize_msgpack_data(data, metadata_fields)
# (pid=18503)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 167, in _deserialize_msgpack_data
# (pid=18503)     python_objects = self._deserialize_pickle5_data(pickle5_data)
# (pid=18503)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 157, in _deserialize_pickle5_data
# (pid=18503)     obj = pickle.loads(in_band)
# (pid=18503) ModuleNotFoundError: No module named 'TWIG_utils'
# (pid=18510) 2023-04-29 12:15:30,863	ERROR serialization.py:253 -- No module named 'TWIG_utils'
# (pid=18510) Traceback (most recent call last):
# (pid=18510)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 251, in deserialize_objects
# (pid=18510)     obj = self._deserialize_object(data, metadata, object_ref)
# (pid=18510)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 189, in _deserialize_object
# (pid=18510)     return self._deserialize_msgpack_data(data, metadata_fields)
# (pid=18510)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 167, in _deserialize_msgpack_data
# (pid=18510)     python_objects = self._deserialize_pickle5_data(pickle5_data)
# (pid=18510)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 157, in _deserialize_pickle5_data
# (pid=18510)     obj = pickle.loads(in_band)
# (pid=18510) ModuleNotFoundError: No module named 'TWIG_utils'
# (pid=18510) 2023-04-29 12:15:30,865	ERROR serialization.py:253 -- No module named 'TWIG_utils'
# (pid=18510) Traceback (most recent call last):
# (pid=18510)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 251, in deserialize_objects
# (pid=18510)     obj = self._deserialize_object(data, metadata, object_ref)
# (pid=18510)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 189, in _deserialize_object
# (pid=18510)     return self._deserialize_msgpack_data(data, metadata_fields)
# (pid=18510)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 167, in _deserialize_msgpack_data
# (pid=18510)     python_objects = self._deserialize_pickle5_data(pickle5_data)
# (pid=18510)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 157, in _deserialize_pickle5_data
# (pid=18510)     obj = pickle.loads(in_band)
# (pid=18510) ModuleNotFoundError: No module named 'TWIG_utils'
# (pid=18510) 2023-04-29 12:15:30,867	ERROR serialization.py:253 -- No module named 'TWIG_utils'
# (pid=18510) Traceback (most recent call last):
# (pid=18510)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 251, in deserialize_objects
# (pid=18510)     obj = self._deserialize_object(data, metadata, object_ref)
# (pid=18510)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 189, in _deserialize_object
# (pid=18510)     return self._deserialize_msgpack_data(data, metadata_fields)
# (pid=18510)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 167, in _deserialize_msgpack_data
# (pid=18510)     python_objects = self._deserialize_pickle5_data(pickle5_data)
# (pid=18510)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 157, in _deserialize_pickle5_data
# (pid=18510)     obj = pickle.loads(in_band)
# (pid=18510) ModuleNotFoundError: No module named 'TWIG_utils'
# ---------------------------------------------------------------------------
# RayTaskError                              Traceback (most recent call last)
# /var/folders/kk/ffqddykx5699q_3lb8rnt68h0000gn/T/ipykernel_17808/3626138888.py in <module>
# ----> 1 stock_data = get_ticker_daily_data(client, stock_list[0], date_start, date_end)
#
# ~/projects/west-investment-group/src/TWIG_utils.py in get_ticker_daily_data(client, ticker, start, end)
#      58     # Use map() to parallelize the function calls
#      59     with Pool() as pool:
# ---> 60          results = pool.map(get_ticker_data, input_data)
#      61
#      62     # Collect the results and remove any None values
#
# ~/projects/twigINV/lib/python3.7/site-packages/ray/util/multiprocessing/pool.py in map(self, func, iterable, chunksize)
#     707
#     708         return self._map_async(
# --> 709             func, iterable, chunksize=chunksize, unpack_args=False).get()
#     710
#     711     def map_async(self,
#
# ~/projects/twigINV/lib/python3.7/site-packages/ray/util/multiprocessing/pool.py in get(self, timeout)
#     274                     raise result.underlying
#     275                 elif isinstance(result, Exception):
# --> 276                     raise result
#     277             results.extend(batch)
#     278
#
# ~/projects/twigINV/lib/python3.7/site-packages/ray/util/multiprocessing/pool.py in run(self)
#     201             [ready_id], unready = ray.wait(unready, num_returns=1)
#     202             try:
# --> 203                 batch = ray.get(ready_id)
#     204             except ray.exceptions.RayError as e:
#     205                 batch = [e]
#
# ~/projects/twigINV/lib/python3.7/site-packages/ray/_private/client_mode_hook.py in wrapper(*args, **kwargs)
#      80         if client_mode_should_convert():
#      81             return getattr(ray, func.__name__)(*args, **kwargs)
# ---> 82         return func(*args, **kwargs)
#      83
#      84     return wrapper
#
# ~/projects/twigINV/lib/python3.7/site-packages/ray/worker.py in get(object_refs, timeout)
#    1562                     worker.core_worker.dump_object_store_memory_usage()
#    1563                 if isinstance(value, RayTaskError):
# -> 1564                     raise value.as_instanceof_cause()
#    1565                 else:
#    1566                     raise value
#
# RayTaskError: ray::PoolActor.run_batch() (pid=18509, ip=192.168.86.78)
#   File "python/ray/_raylet.pyx", line 493, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 514, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 384, in ray._raylet.raise_if_dependency_failed
# ray.exceptions.RaySystemError: System error: No module named 'TWIG_utils'
# traceback: Traceback (most recent call last):
#   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 251, in deserialize_objects
#     obj = self._deserialize_object(data, metadata, object_ref)
#   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 189, in _deserialize_object
#     return self._deserialize_msgpack_data(data, metadata_fields)
#   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 167, in _deserialize_msgpack_data
#     python_objects = self._deserialize_pickle5_data(pickle5_data)
#   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 157, in _deserialize_pickle5_data
#     obj = pickle.loads(in_band)
# ModuleNotFoundError: No module named 'TWIG_utils'

# %%
stock_data
# Out:
# Empty DataFrame
# Columns: [date, open, close, high, low, ticker]
# Index: []
