# %%
import sys
sys.path.append('../src/')
from TWIG_utils import *

# %%
stock_list = ['AMZN', 'TSLA', 'SNAP', 'INTC', 'PINS', 'SOFI', 'APPLE', 'F', 'BAC', 'T', 'GOOGL']
date_start = '2022-01-01'
date_end = '2023-04-28'

client = RESTClient(auth_key="JeeOjlOPBe5aTiQ_Jb39raRqlam45uAO")

# %%
stock_data = get_ticker_daily_data(client, stock_list[0], date_start, date_end)
# Out:
# Starting data pull for AMZN...
# 2023-04-29 12:24:24,347	INFO services.py:1247 -- View the Ray dashboard at http://127.0.0.1:8265
# (pid=18916) 2023-04-29 12:24:26,022	ERROR serialization.py:253 -- No module named 'TWIG_utils'
# (pid=18916) Traceback (most recent call last):
# (pid=18916)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 251, in deserialize_objects
# (pid=18916)     obj = self._deserialize_object(data, metadata, object_ref)
# (pid=18916)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 189, in _deserialize_object
# (pid=18916)     return self._deserialize_msgpack_data(data, metadata_fields)
# (pid=18916)   File "/Users/adampetranovich/projects/twigINV/lib/python3.7/site-packages/ray/serialization.py", line 167, in _deserialize_msgpack_data
# (pid=18916)     python_objects = self._deserialize_pickle5_data(pickle5_data)
# ...

# %%
stock_data
# Out:
# Empty DataFrame
# Columns: [date, open, close, high, low, ticker]
# Index: []

# %%
import os

# %%
os.environ
# Out:
# environ{'TERM_PROGRAM': 'Apple_Terminal',
#         'SHELL': '/bin/bash',
#         'TERM': 'xterm-color',
#         'TMPDIR': '/var/folders/kk/ffqddykx5699q_3lb8rnt68h0000gn/T/',
#         'Apple_PubSub_Socket_Render': '/private/tmp/com.apple.launchd.nfYBsCtxOi/Render',
#         'TERM_PROGRAM_VERSION': '421.2',
#         'OLDPWD': '/Users/adampetranovich/projects/west-investment-group',
#         'TERM_SESSION_ID': '70FC32D7-CBAF-4CF2-95B5-302407D7BB0C',
#         'USER': 'adampetranovich',
#         'SSH_AUTH_SOCK': '/private/tmp/com.apple.launchd.A5pvJKLc2T/Listeners',
#         'VIRTUAL_ENV': '/Users/adampetranovich/projects/twigINV',
#         'PATH': '/Users/adampetranovich/projects/twigINV/bin:/Users/adampetranovich/Library/Python/3.7/bin:/Users/adampetranovich/usr/bin/python:/usr/local/bin:/usr/bin:/bin:/usr/sbin:/sbin:/usr/local/munki',
#         'PWD': '/Users/adampetranovich/projects/west-investment-group/notebooks',
#         'LANG': 'en_US.UTF-8',
# ...
